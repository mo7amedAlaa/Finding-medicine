# %%
from tkinter import *
from experta import *

# %%
class FindMedicine(KnowledgeEngine):
    @DefFacts()
    def _initial_action(self):
        yield Fact(action="find_medicine")
        form1 = Tk()
        form1.title("Medical system")
        form1.config(background='pink')
        fr1 = Frame(width='900', height='600', background='pink')
        fr1.place(x=10, y=10)
        form1.geometry("900x800")
        lb0 = Label(form1, justify='center', font=5,text="Hi! I will help you find the right medication for you.\nFor that you'll have to answer a few questions about your conditions\nDo you feel any of the following symptoms:",bg="#123456", fg="#fff",width="800")
        lb0.pack()
        #################################################################################
        lb1 = Label(form1, text="Dizzines:", bg='white', font=5)
        en1 = Entry(form1, justify='center', font=5)
        lb1.place(x=160, y=100)
        en1.place(x=450, y=100)
        #################################################################################
        lb2 = Label(form1, text="nausea:", bg='white', font=5)
        en2 = Entry(form1, justify='center', font=5)
        lb2.place(x=160, y=140)
        en2.place(x=450, y=140)
        #################################################################################
        lb3 = Label(form1, text="Weight loss:", bg='white', font=5)
        en3 = Entry(form1, justify='center', font=5)
        lb3.place(x=160, y=180)
        en3.place(x=450, y=180)
        #################################################################################
        lb4 = Label(form1, text="Difficulty swallowing:", bg='white', font=5)
        en4 = Entry(form1, justify='center', font=5)
        lb4.place(x=160, y=220)
        en4.place(x=450, y=220)
        #################################################################################
        lb5 = Label(form1, text="dyspnea:", bg='white', font=5)
        en5 = Entry(form1, justify='center', font=5)
        lb5.place(x=160, y=260)
        en5.place(x=450, y=260)
        #################################################################################
        lb6 = Label(form1, text="extreme thirst:", bg='white', font=5)
        en6 = Entry(form1, justify='center', font=5)
        lb6.place(x=160, y=300)
        en6.place(x=450, y=300)
        #################################################################################
        lb7 = Label(form1, text="headcahe:", bg='white', font=5)
        en7 = Entry(form1, justify='center', font=5)
        lb7.place(x=160, y=340)
        en7.place(x=450, y=340)
        #################################################################################
        lb8 = Label(form1, text="slow or fast heartbeat:", bg='white', font=5)
        en8 = Entry(form1, justify='center', font=5)
        lb8.place(x=160, y=380)
        en8.place(x=450, y=380)
        ################################################################################
        lb9 = Label(form1, text="flatulence:", bg='white', font=5)
        en9 = Entry(form1, justify='center', font=5)
        lb9.place(x=160, y=420)
        en9.place(x=450, y=420)
        ################################################################################
        lb10 = Label(form1, text="yellow of the skin and eyes:", bg='white', font=5)
        en10 = Entry(form1, justify='center', font=5)
        lb10.place(x=160, y=460)
        en10.place(x=450, y=460)
        ################################################################################
        lb11 = Label(form1, text="vomiting:", bg='white', font=5)
        en11 = Entry(form1, justify='center', font=5)
        lb11.place(x=160, y=500)
        en11.place(x=450, y=500)
        ################################################################################
        lb12 = Label(form1, text="excessive sweating:", bg='white', font=5)
        en12 = Entry(form1, justify='center', font=5)
        lb12.place(x=160, y=540)
        en12.place(x=450, y=540)
        ################################################################################
        lb13 = Label(form1, text="tummy ache:", bg='white', font=5)
        en13 = Entry(form1, justify='center', font=5)
        lb13.place(x=160, y=580)
        en13.place(x=450, y=580)
        ################################################################################
        lb14 = Label(form1, text="increase saliva secretion:", bg='white', font=5)
        en14 = Entry(form1, justify='center', font=5)
        lb14.place(x=160, y=620)
        en14.place(x=450, y=620)
        ################################################################################
        lb15 = Label(form1, text="redness and swelling of tonsils:", bg='white', font=5)
        en15 = Entry(form1, justify='center', font=5)
        lb15.place(x=160, y=660)
        en15.place(x=450, y=660)
        #################################################################################
        def get_values():
            self.declare(Fact(Dizzines=en1.get()))
            self.declare(Fact(nausea=en2.get()))
            self.declare(Fact(Weight_loss=en3.get()))
            self.declare(Fact(Difficulty_swallowing=en4.get()))
            self.declare(Fact(dyspnea=en5.get()))
            self.declare(Fact(extreme_thirst=en6.get()))
            self.declare(Fact(headcahe=en7.get()))
            self.declare(Fact(slow_or_fast_heartbeat=en8.get()))
            self.declare(Fact(flatulence=en9.get()))
            self.declare(Fact(yellow_of_the_skin_eyes=en10.get()))
            self.declare(Fact(vomiting=en11.get()))
            self.declare(Fact(excessive_sweating=en12.get()))
            self.declare(Fact(tummy_ache=en13.get()))
            self.declare(Fact(increase_saliva_secretion=en14.get()))
            self.declare(Fact(redness_swelling_of_tonsils=en15.get()))
        #############################################################################
        btn = Button(form1,command=get_values,text="submit",bg="#123456", fg="#fff", font=5 ,padx='50')
        btn.place(x=400,y=720)
        form1.mainloop()
        #####################################################################
    @Rule(Fact(Dizzines='yes'), Fact(extreme_thirst='yes'))
    def medicine_0(self):
        self.declare(Fact(medicine="you should take Dolcyl"))
        #####################################################################
    @Rule(Fact(Dizzines='yes'), Fact(dyspnea='yes'),Fact(headcahe='yes'))
    def medicine_1(self):
        self.declare(Fact(medicine="you should take nevilob"))
        ######################################################################
    @Rule(Fact(Dizzines='yes'), Fact(dyspnea='yes'),Fact(slow_or_fast_heartbeat='yes'))
    def medicine_2(self):
        self.declare(Fact(medicine="you should take Concor"))
       ######################################################################
    @Rule(Fact(nausea='yes'), Fact(flatulence='yes'),Fact(yellow_of_the_skin_and_eyes='yes'))
    def medicine_3(self):
        self.declare(Fact(medicine="you should take Baraclude"))
      ######################################################################
    @Rule(Fact(nausea='yes'), Fact(flatulence='yes'),Fact(vomiting='yes'))
    def medicine_4(self):
        self.declare(Fact(medicine="you should take pepzol"))
     ######################################################################
    @Rule(Fact(Weight_loss='yes'), Fact(excessive_sweating='yes'))
    def medicine_5(self):
        self.declare(Fact(medicine="you should take eltroxin"))
     ######################################################################
    @Rule(Fact(Weight_loss='yes'), Fact(tummy_ache='yes'))
    def medicine_6(self):
        self.declare(Fact(medicine="you should take librax"))
    ######################################################################
    @Rule(Fact(Difficulty_swallowing='yes'), Fact(increase_saliva_secretion='yes'))
    def medicine_7(self):
        self.declare(Fact(medicine="you should take aluminum_hydrixide"))
    ######################################################################
    @Rule(Fact(Difficulty_swallowing='yes'), Fact(redness_swelling_of_tonsils='yes'))
    def medicine_8(self):
        self.declare(Fact(medicine="you should take septrin"))
    #####################################################################
    @Rule(Fact(medicine=MATCH.medicine))
    def disease(self,medicine):
        print("")
        id_medicine = medicine
        form2 = Tk()
        form2.title("Medical system answer")
        form2.geometry("800x200")
        lb0 = Label(form2,text="the result is",bg="#123456", fg="#fff",width="800", font=5)
        lb0.pack()
        var = StringVar()
        var.set(id_medicine)
        lb1 = Label(form2, textvariable = var,bg="#678954", fg="#fff",width="800",height="20", font=5)
        lb1.pack()
        form2.mainloop()

engine = FindMedicine()
while(1):
    engine.reset()  
    engine.run()  
    print("Would you like to search for medicine again?")
    if input() == "no":
        break;
